# %%
import pandas as pd

# %%
file1 = "temperature.csv"
file2 = "weather_description.csv"

# %%
temp_df = pd.read_csv(file1)
condition_df = pd.read_csv(file2)
condition_df.head()
# Out:
#               datetime      Vancouver          Portland San Francisco  \
# 0  2012-10-01 12:00:00            NaN               NaN           NaN
# 1  2012-10-01 13:00:00           mist  scattered clouds    light rain
# 2  2012-10-01 14:00:00  broken clouds  scattered clouds  sky is clear
# 3  2012-10-01 15:00:00  broken clouds  scattered clouds  sky is clear
# 4  2012-10-01 16:00:00  broken clouds  scattered clouds  sky is clear
#
#         Seattle   Los Angeles     San Diego     Las Vegas       Phoenix  \
# 0           NaN           NaN           NaN           NaN           NaN
# 1  sky is clear          mist  sky is clear  sky is clear  sky is clear
# 2  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 3  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
# 4  sky is clear  sky is clear  sky is clear  sky is clear  sky is clear
#
#     Albuquerque       ...          Philadelphia    New York         Montreal  \
# ...

# %%
temp_df.head()
# Out:
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0  2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3  2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4  2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque    ...      \
# 0          NaN         NaN         NaN         NaN          NaN    ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000    ...
# 2   291.868186  291.533501  293.403141  296.608509   285.154558    ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952    ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345    ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# ...

# %%
len(temp_df["Kansas City"])
# Out:
# 45253

# %%
len(condition_df["Kansas City"])
# Out:
# 45253

# %%
kc_temp = pd.DataFrame(temp_df["datetime"])
kc_temp["Temperature (K)"] = temp_df["Kansas City"]
kc_temp = kc_temp.rename(columns={"datetime":"Date/Time"})

# %%
kc_temp.head()
# Out:
#              Date/Time  Temperature (K)
# 0  2012-10-01 12:00:00              NaN
# 1  2012-10-01 13:00:00       289.980000
# 2  2012-10-01 14:00:00       289.997635
# 3  2012-10-01 15:00:00       290.038151
# 4  2012-10-01 16:00:00       290.078666

# %%
kc_cond = pd.DataFrame(condition_df["datetime"])
kc_cond["Condition"] = condition_df["Kansas City"]
kc_cond = kc_cond.rename(columns={"datetime":"Date/Time"})

# %%
kc_cond.head()
# Out:
#              Date/Time     Condition
# 0  2012-10-01 12:00:00           NaN
# 1  2012-10-01 13:00:00  sky is clear
# 2  2012-10-01 14:00:00  sky is clear
# 3  2012-10-01 15:00:00  sky is clear
# 4  2012-10-01 16:00:00  sky is clear

# %%
kc_df = pd.merge(kc_temp, kc_cond, on="Date/Time")
kc_df.head()
# Out:
#              Date/Time  Temperature (K)     Condition
# 0  2012-10-01 12:00:00              NaN           NaN
# 1  2012-10-01 13:00:00       289.980000  sky is clear
# 2  2012-10-01 14:00:00       289.997635  sky is clear
# 3  2012-10-01 15:00:00       290.038151  sky is clear
# 4  2012-10-01 16:00:00       290.078666  sky is clear

# %%
kc_weather = kc_df.loc[kc_df["Date/Time"] > "2016-01-01 12:00", :]
kc_weather.head()
# Out:
#                  Date/Time  Temperature (K)     Condition
# 28488  2016-01-01 12:00:00           268.19  sky is clear
# 28489  2016-01-01 13:00:00           267.68  sky is clear
# 28490  2016-01-01 14:00:00           268.46  sky is clear
# 28491  2016-01-01 15:00:00           269.68  sky is clear
# 28492  2016-01-01 16:00:00           271.83  sky is clear

# %%
kc_weather["Temperature (F)"] = (1.8*(kc_weather["Temperature (K)"]-273)+32)
# Out:
# C:\Users\alfan\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
kc_weather.head()
# Out:
#                  Date/Time  Temperature (K)     Condition  Temperature (F)
# 28488  2016-01-01 12:00:00           268.19  sky is clear           23.342
# 28489  2016-01-01 13:00:00           267.68  sky is clear           22.424
# 28490  2016-01-01 14:00:00           268.46  sky is clear           23.828
# 28491  2016-01-01 15:00:00           269.68  sky is clear           26.024
# 28492  2016-01-01 16:00:00           271.83  sky is clear           29.894

# %%
kc_weather["Condition"].unique()
# Out:
# array(['sky is clear', 'light rain', 'scattered clouds',
#        'overcast clouds', 'broken clouds', 'few clouds',
#        'light intensity drizzle', 'mist', 'light snow', 'moderate rain',
#        'haze', 'snow', 'shower drizzle', 'heavy intensity rain',
#        'squalls', 'thunderstorm with heavy rain', 'fog',
#        'proximity thunderstorm', 'thunderstorm with light rain',
#        'thunderstorm', 'very heavy rain', 'drizzle',
#        'proximity shower rain', 'shower rain',
#        'light intensity shower rain', 'heavy intensity shower rain',
#        'freezing rain', 'thunderstorm with rain'], dtype=object)

# %%
category = {'sky is clear' : 'clear', 'light rain' : 'rain', 'scattered clouds' : 'clear',
       'overcast clouds' : 'clear', 'broken clouds' : 'clear', 'few clouds' : 'clear',
       'light intensity drizzle' : 'rain', 'mist' : 'rain', 'light snow' : 'snow', 'moderate rain' : 'rain',
       'haze' : 'other', 'snow' : 'snow', 'shower drizzle' : 'rain', 'heavy intensity rain' : 'rain',
       'squalls' : 'rain', 'thunderstorm with heavy rain':'rain', 'fog': 'other',
       'proximity thunderstorm': 'rain', 'thunderstorm with light rain':'rain',
       'thunderstorm':'rain', 'very heavy rain':'rain', 'drizzle':'rain',
       'proximity shower rain':'rain', 'shower rain':'rain',
       'light intensity shower rain':'rain', 'heavy intensity shower rain':'rain',
       'freezing rain':'rain', 'thunderstorm with rain':'rain'}

# %%
condition_list = []

for index, row in kc_weather.iterrows():
    condition_list.append(category[row['Condition']])

# %%
kc_weather["classification"] = condition_list
# Out:
# C:\Users\alfan\AppData\Local\conda\conda\envs\PythonData\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':

# %%
kc_weather.head()
# Out:
#                  Date/Time  Temperature (K)     Condition  Temperature (F)  \
# 28488  2016-01-01 12:00:00           268.19  sky is clear           23.342
# 28489  2016-01-01 13:00:00           267.68  sky is clear           22.424
# 28490  2016-01-01 14:00:00           268.46  sky is clear           23.828
# 28491  2016-01-01 15:00:00           269.68  sky is clear           26.024
# 28492  2016-01-01 16:00:00           271.83  sky is clear           29.894
#
#       classification
# 28488          clear
# 28489          clear
# 28490          clear
# 28491          clear
# 28492          clear
